# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import random

import pandas as pd

# %%
# 데이터 리스트 초기화
title_list = []
likes_list = []
singer_list = []
lyrics_list = []

driver = webdriver.Chrome()

random_sec = random.uniform(0, 0.1)
i = 0
j = 0

start_num = 30 # 크롤링 시작 페이지
end_num = 40 # 크롤링 종료 페이지

for i in range(start_num, end_num):
    i = i * 50 + 1
    url = "https://www.melon.com/genre/song_list.htm?gnrCode=GN0100#params%5BgnrCode%5D=GN0100&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex={}".format(i)
    driver.get(url)
    time.sleep(3)
    for j in range(1, 51):
        try:
            time.sleep(random_sec) # 크롤링 차단 방지를 위한 time sleep
            url2 = "/html/body/div/div[3]/div/div/div[5]/form/div/table/tbody/tr[{}]/td[4]/div/a".format(j) # 곡 세부정보 태그
            element = driver.find_element(By.XPATH, url2)
            element.click()
            title = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[1]/div[1]") # 곡 제목
            likes = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[3]/button[1]/span[2]") # 좋아요 수
            singer = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[1]/div[2]/a/span[1]") # 가수
            lyrics = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/div[2]/div[2]/div") # 가사
            print ("{}번째 곡".format(i+j-1))
            print ("Title :",title.text)
            title_list.append(title.text)
            likes_list.append(likes.text)
            singer_list.append(singer.text)
            lyrics_list.append(lyrics.text)
            driver.back()
            j += 1
        except:
            driver.back()
            print("{}번째 곡 오류".format(i+j-1))
            j += 1
    driver.back()
    i += 1 
driver.quit()
# Out:
# 1501번째 곡
# Title : 향기
# 1502번째 곡
# Title : 비가 내리는 밤이면
# 1503번째 곡
# Title : 처음이니까
# 1504번째 곡
# Title : 세글자
# 1505번째 곡
# Title : 내일의 우리
# 1506번째 곡
# Title : 너에게 닿을게
# 1507번째 곡
# Title : 하루끝엔 그대가 있어요
# 1508번째 곡
# Title : 내가 그댈
# 1509번째 곡
# Title : 있어줄래
# 1510번째 곡
# Title : 환청 (Feat. 나쑈 (NaShow))
# 1511번째 곡
# Title : 취중고백
# 1512번째 곡
# Title : 제발
# 1513번째 곡
# Title : 행복하니
# 1514번째 곡
# Title : 다시 사랑할 수 있게
# 1515번째 곡
# Title : 술이 너보다 낫더라
# 1516번째 곡
# Title : 화분 (알렉스 Ver.) (우리결혼했어요 삽입곡)
# 1517번째 곡
# Title : 영원 (Forever)
# 1518번째 곡
# Title : 오직 너만
# 1519번째 곡
# Title : 비가 오면 마음껏 울어도 되니까
# 1520번째 곡
# Title : 사랑이 지나가면
# 1521번째 곡
# Title : 추억은 한 편의 산문집 되어
# 1522번째 곡
# Title : 나 항상 그대를
# 1523번째 곡
# Title : 괜찮아
# 1524번째 곡
# Title : 오늘 서울은 하루종일 맑음 (Vocal 윤하)
# 1525번째 곡
# Title : 사랑하는 당신께
# 1526번째 곡
# Title : 혼자만 하는 사랑
# 1527번째 곡
# Title : 그때 또 다시 (Again)
# 1528번째 곡
# Title : 이것밖에
# 1529번째 곡
# Title : 너 하나 빼는 일
# 1530번째 곡
# Title : 빨래
# 1531번째 곡
# Title : 소리쳐
# 1532번째 곡
# Title : 헤어지기 싫어
# 1533번째 곡
# ...

# %%
data = {"Title" : title_list,"Likes":likes_list, "Singer":singer_list, "Lyrics":lyrics_list}
df = pd.DataFrame(data)

if (end_num - start_num)*50 == len(df) : 
  print("완료")
  df.to_csv('songs(발라드 {} ~ {}).csv'.format(start_num*50 + 1, end_num*50), index=False)
else : 
  print("미완료")
  print("{}개 누락".format((end_num - start_num)*50 - len(df)))
# Out:
# 완료

# %%
df.to_csv('songs(발라드 {} ~ {}).csv'.format(start_num*50 + 1, end_num*50), index=False)
