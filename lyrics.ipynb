# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import pandas as pd
#import MySQLdb
import sklearn

import konlpy
from konlpy.tag import Twitter

import gensim
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
from gensim import corpora, models
from gensim.models import LdaMulticore
from gensim.models import Word2Vec
from gensim.corpora import Dictionary, MmCorpus

import pyLDAvis
import pyLDAvis.gensim
import pickle

from wordcloud import WordCloud
from collections import Counter

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE


from os import path
#from bokeh.plotting import figure, show, output_notebook
#from bokeh.models import HoverTool, ColumnDataSource
#output_notebook()

# %%
driver = webdriver.Chrome()
driver.get("http://www.melon.com/genre/song_list.htm?gnrCode=GN0200")

lyric_page = driver.find_element(By.XPATH, "//a[@class='btn button_icons type03 song_info']")
lyric_page.click()

title = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[1]/div[1]")
print ("제목 :",title.text)

likes = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[3]/button[1]/span[2]")
print ("좋아요 :",likes.text)

singer = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/form/div/div/div[2]/div[1]/div[2]/a/span[1]")
print ("가수 :",singer.text)

lyrics = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div/div/div/div[2]/div[2]/div")
print ("가사 :")
print (lyrics.text)
# Out:
# 제목 : Locked On
# 좋아요 : 31
# 가수 : VVUP(비비업)
# 가사 :
# Mm..Don ́t you worry...yeah
#
# Why you look like December?
# You say you freezing up inside wanna surrender
# Oh Why? Why?
# Ah! Ain’t even winter!
# 기억나게 해줄게 I'm bringing back your summer
#
# Don't let go 여기는 one way
# 나만 봐 널 위해 부를께
# Shout Baby! Shout Baby!
# You know that I be Proud Baby! Proud Baby!
# You got it ya ya
#
# 끝이란 건 의미 없어
# We will find
# 다시 돌아갈 수 있게
# If you want it
# I got it
# I let it
# You have it
#
# 어떤 상황이 와도
# You just put your hand in mine
# Baby leave it all behind
# Cause we now two
#
# Because my love is coming strong
# There’s nothing wrong
# My heart on you locked on
#
# Don’t worry Don ́t worry Oo Don’t worry Don ́t worry Ah Don’t worry Don ́t worry
# Cause one and one that equals two
# You know that it’s true Oho
#
# Don’t worry Don ́t worry let it go
# Don’t worry I’m still the one that you know
#
# Just get it
# Love is coming strong
# Never be alone cause my heart on you is locked on
#
# Yeah we go up and down
# But we are side by side
# Still giving me the first time feeling of my life
# Oo got me flying with you
# Takes me higher with you
# Baby always
# I just wanna feel da way
#
# Cause you got the thing that I need
# 내 미래의 꿈같은 ride, ride, ride, ride, ride, ride
# Cause you do me right, right, right, right, right, right
#
# That’s what you do
#
# 끝이란 건 의미 없어
# We will find
# 다시 돌아갈 수 있게
# If you want it
# I got it
# I let it
# You have it
#
# 어떤 상황이 와도
# You just put your hand in mine
# Baby leave it all behind
# Cause we now two
#
# Because my love is coming strong
# There’s nothing wrong
# My heart on you locked on
#
# Don’t worry Don ́t worry Oo Don’t worry Don ́t worry Ah Don’t worry Don ́t worry
# Cause one and one that equals two
# You know that it’s true Oho
#
# Don’t worry Don ́t worry let it go
# Don’t worry I’m still the one that you know
#
# Just get it
# Love is coming strong
# Never be alone cause my heart on you is locked on
#
# 딴 길로 새어 가도
# 잊지 말아줘
# That I will remember who you are
# I will bring heaven back on earth
#
# So get ready let’s get ready we gon’ livin it up
# Come get ready let’s get steady we gon’ livin it up
#
# Don’t worry in this story
# Cause my heart is always locked on ya
#
# Always locked on
#
# Don’t worry Don ́t worry Oo Don’t worry Don ́t worry Ah Don’t worry Don ́t worry
# Cause one and one that equals two
# You know that it’s true Oho
#
# Don’t worry Don ́t worry let it go
# Don’t worry I’m still the one that you know
#
# Just get it
# Love is coming strong
# Never be alone cause my heart on you is locked on
