# %%
import pandas as pd

# %%
#df = pd.read_csv('댄스_3236 곡_240404).csv')       #3236->3225
#df = pd.read_csv('발라드_4841곡_240402.csv')       #4841->4836
#df = pd.read_csv('발라드_4999곡_240402.csv')        #4999->4995
#df = pd.read_csv('알앤비_4927곡_240402.csv')       #4927->4889
#df = pd.read_csv('인디_5000곡_240402.csv')         #5000->4938
#df = pd.read_csv('트로트_4990곡_240404.csv')        #4990->4721
#df = pd.read_csv('락메탈.csv')                      #4834->4794
#df = pd.read_csv('해외팝.csv')                      #4744->4118
#df = pd.read_csv('songs_rawdata/해외락_4544.csv')   #4544->3846
#df = pd.read_csv('songs_rawdata/해외포크_2738.csv')     #2738->1524
#df = pd.read_csv('songs_rawdata/해외힙합_4498.csv')     #4498->2729
df = pd.read_csv('songs_rawdata/해외알앤비_4442.csv')     #4442->3336
#df = df.iloc[:, 1:]
print(len(df))
print(df.isnull().sum())
# Out:
# 4442
# Title     0
# Likes     0
# Singer    0
# Lyrics    0
# dtype: int64

# %%
#알앤비 파일에 제목이 'N/A'인 노래 존재
#df = df.fillna('N/A')
#df[df['Singer'] == '주영']
# Out:
#                          Title   Likes Singer  \
# 1040           처음 (Feat. SOLE)  27,485     주영
# 1074           처음 (Feat. SOLE)  27,486     주영
# 1480        PRADA (Feat. pH-1)  19,670     주영
# 2742                     Fever     243     주영
# 2744             아름 (Feat. 죠지)   9,655     주영
# 3136  Planet Girl (Feat. pH-1)   7,323     주영
# 3534     Door (Feat. Beenzino)   7,990     주영
# 3619     요를 붙이는 사이 (Feat. 헤이즈)   4,737     주영
# 4131       Wine (Feat. G.Soul)   6,172     주영
# 4175                       N/A   6,040     주영
#
#                                                  Lyrics
# 1040  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1074  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1480  때론 아무 생각도\r\n나질 않아 너의 기억도\r\n그저 별일 없었어\r\n아른거림...
# 2742  Looking now, There are seasons in our tale\r\n...
# 2744  너와 내가 눈을 맞출 때\r\n닫혀있던 내가 열릴 때\r\nnever thought...
# 3136  Damn\r\nGirl you got me thinkin of\r\nWith bot...
# 3534  길을 잃은 것 같아\r\n언제부터였는지\r\n모든 것이 낯설어\r\n보이지도 않는 ...
# 3619  운명은 아니겠지\r\n우연이거나 착각일 거야\r\n드라마는 없어\r\n어젯밤의\r\...
# 4131  와인 잔에 우리 기억이 담겨\r\n비워낼수록 점점 멀어져\r\n쏟아버리고\r\n깨어...
# 4175  늘 그랬듯 쉬운 건\r\n하나 없어 거울 앞에 난\r\nTrying to wave ...

# %%
df.head()
# Out:
#                     Title    Likes       Singer  \
# 0               Like I Do   31,459      J.Tajor
# 1  HEARTBREAK ANNIVERSARY   90,539       Giveon
# 2             At My Worst  127,901  Pink Sweat$
# 3     When I Was Your Man  134,423   Bruno Mars
# 4        Someone Like You  189,714        Adele
#
#                                               Lyrics
# 0  (Intro)\nYeah-eah-eah\n\nThat's a drop-top cou...
# 1  HEARTBREAK ANNIVERSARY - Giveon\nOoh oh woah\n...
# 2  Can I call you baby\nCan you be my friend\nCan...
# 3  Same bed but it feels just\nA little bit bigge...
# 4  I heard That you're settled down\nThat you Fou...

# %%
df[df['Lyrics'].str.contains('멜론 회원')]
# Out:
#                             Title  Likes           Singer  \
# 58                    Made For Me  1,740        Muni Long
# 115               i know it’s you     11          Narysal
# 132                          IC+B  1,665        Thomas Ng
# 136                   Not The One     66    Dana Williams
# 146                Walk Like This    373              FLO
# ...                           ...    ...              ...
# 4403  No Limit (Feat. Young Thug)    818            Usher
# 4404          Down (Feat. Adrian)  2,347          Xamvolo
# 4405                Time For Love    833  Mayer Hawthorne
# 4416               Talking Insane    332         Theodora
# 4423                Wait A Minute    387           Ayanis
#
#                                             Lyrics
# 58    [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 115   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 132   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 136   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 146   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# ...                                            ...
# 4403  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4404  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4405  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4416  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4423  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
#
# [992 rows x 4 columns]

# %%
df[df['Lyrics'].str.contains('성인 인증')]
# Out:
#                           Title    Likes         Singer  \
# 39                       2 soon  118,770          keshi
# 93                        Woman    8,070       Doja Cat
# 109               The Lazy Song   25,532     Bruno Mars
# 118   Starboy (Feat. Daft Punk)   37,972     The Weeknd
# 203                   The Hills   19,045     The Weeknd
# ...                         ...      ...            ...
# 4148                 I Like Dat      418         T-Pain
# 4237              I'M THAT GIRL      401        Beyonce
# 4295                    Forever      822    Chris Brown
# 4313                    Will He    3,008           Joji
# 4361            Dat Right There      349  Summer Walker
#
#                                                  Lyrics
# 39    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 93    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 109   청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 118   청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 203   청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# ...                                                 ...
# 4148  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4237  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4295  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4313  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4361  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
#
# [114 rows x 4 columns]

# %%
df = df[~df['Lyrics'].str.contains('멜론 회원|성인 인증')].reset_index(drop = True)
print(len(df))
df.head()
# Out:
# 3336
#                     Title    Likes       Singer  \
# 0               Like I Do   31,459      J.Tajor
# 1  HEARTBREAK ANNIVERSARY   90,539       Giveon
# 2             At My Worst  127,901  Pink Sweat$
# 3     When I Was Your Man  134,423   Bruno Mars
# 4        Someone Like You  189,714        Adele
#
#                                               Lyrics
# 0  (Intro)\nYeah-eah-eah\n\nThat's a drop-top cou...
# 1  HEARTBREAK ANNIVERSARY - Giveon\nOoh oh woah\n...
# 2  Can I call you baby\nCan you be my friend\nCan...
# 3  Same bed but it feels just\nA little bit bigge...
# 4  I heard That you're settled down\nThat you Fou...

# %%
df.to_csv('eng_rnb.csv', index = False)
