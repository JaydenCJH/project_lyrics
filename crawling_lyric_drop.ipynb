# %%
import pandas as pd

# %%
#df = pd.read_csv('댄스_3236 곡_240404).csv')       #3236->3225
#df = pd.read_csv('발라드_4841곡_240402.csv')       #4841->4836
#df = pd.read_csv('발라드_4999곡_240402.csv')        #4999->4995
#df = pd.read_csv('알앤비_4927곡_240402.csv')       #4927->4889
#df = pd.read_csv('인디_5000곡_240402.csv')         #5000->4938
#df = pd.read_csv('트로트_4990곡_240404.csv')        #4990->4721
#df = pd.read_csv('락메탈.csv')                      #4834->4794
#df = pd.read_csv('해외팝.csv')                      #4744->4118
#df = pd.read_csv('songs_rawdata/해외락_4544.csv')   #4544->3846
#df = pd.read_csv('songs_rawdata/해외포크_2738.csv')     #2738->1524
#df = pd.read_csv('songs_rawdata/해외힙합_4498.csv')     #4498->2729
#df = pd.read_csv('songs_rawdata/해외알앤비_4442.csv')     #4442->3336
df = pd.read_csv('songs_rawdata/한국포크_4724.csv')         #4724->4482
#df = df.iloc[:, 1:]
print(len(df))
print(df.isnull().sum())
# Out:
# 4724
# Title     0
# Likes     0
# Singer    0
# Lyrics    0
# dtype: int64

# %%
#알앤비 파일에 제목이 'N/A'인 노래 존재
#df = df.fillna('N/A')
#df[df['Singer'] == '주영']
# Out:
#                          Title   Likes Singer  \
# 1040           처음 (Feat. SOLE)  27,485     주영
# 1074           처음 (Feat. SOLE)  27,486     주영
# 1480        PRADA (Feat. pH-1)  19,670     주영
# 2742                     Fever     243     주영
# 2744             아름 (Feat. 죠지)   9,655     주영
# 3136  Planet Girl (Feat. pH-1)   7,323     주영
# 3534     Door (Feat. Beenzino)   7,990     주영
# 3619     요를 붙이는 사이 (Feat. 헤이즈)   4,737     주영
# 4131       Wine (Feat. G.Soul)   6,172     주영
# 4175                       N/A   6,040     주영
#
#                                                  Lyrics
# 1040  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1074  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1480  때론 아무 생각도\r\n나질 않아 너의 기억도\r\n그저 별일 없었어\r\n아른거림...
# 2742  Looking now, There are seasons in our tale\r\n...
# 2744  너와 내가 눈을 맞출 때\r\n닫혀있던 내가 열릴 때\r\nnever thought...
# 3136  Damn\r\nGirl you got me thinkin of\r\nWith bot...
# 3534  길을 잃은 것 같아\r\n언제부터였는지\r\n모든 것이 낯설어\r\n보이지도 않는 ...
# 3619  운명은 아니겠지\r\n우연이거나 착각일 거야\r\n드라마는 없어\r\n어젯밤의\r\...
# 4131  와인 잔에 우리 기억이 담겨\r\n비워낼수록 점점 멀어져\r\n쏟아버리고\r\n깨어...
# 4175  늘 그랬듯 쉬운 건\r\n하나 없어 거울 앞에 난\r\nTrying to wave ...

# %%
df.head()
# Out:
#     Title    Likes     Singer  \
# 0  후라이의 꿈  124,398  AKMU (악뮤)
# 1    연애편지   52,065        임영웅
# 2       숲  111,702        최유리
# 3   그라데이션  166,868       10CM
# 4   나만, 봄  201,198     볼빨간사춘기
#
#                                               Lyrics
# 0  저 거위도 벽을 넘어 하늘을 날을 거라고\r\n달팽이도 넓고 거친 바다 끝에 꿈을 ...
# 1  노을에 물든 저녁 하늘이\r\n오랜만에 참 좋은 저녁입니다\r\n문득 떠오른 그대 ...
# 2  난 저기 숲이 돼볼게\r\n너는 자그맣기만 한 언덕 위를\r\n오르며 날 바라볼래\...
# 3  밤은 다시 길고 깊어졌네\r\n나는 점점 너로 잠 못 들게 돼\r\n글로 적어내긴 ...
# 4  안돼 그만둬 거기까지 해\r\n더 다가가면 너 정신 못 차려\r\n안돼 그만해 꽃은...

# %%
df[df['Lyrics'].str.contains('멜론 회원')]
# Out:
#          Title  Likes  Singer                                          Lyrics
# 432         찻잔    858    노고지리  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 645         편지    212     이장희  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 698        옛사랑    104  사월과 오월  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 1060   어서 말을 해    249     유익종  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 1181  삼포로 가는 길    200     강은철  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# ...        ...    ...     ...                                             ...
# 4697        봄비     42     이은하  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 4698    조용한 미소     36     이은하  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 4704    사랑의 썰물      9     위일청  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 4709   시간이 지나도  1,077     홍이삭  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
# 4716   장미 한 송이     36  사랑과 평화  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\r\n가사등록하기
#
# [236 rows x 4 columns]

# %%
df[df['Lyrics'].str.contains('성인 인증')]
# Out:
#           Title   Likes              Singer  \
# 715      어제 차이고  20,507  스텔라장 (Stella Jang)
# 1250   Kingstar   7,655                10CM
# 2095  Hey Billy   3,926                10CM
# 3430     어제 차이고   9,673  스텔라장 (Stella Jang)
# 3856       푸른자살   3,423               푸른 새벽
# 4700    담배왕 스모킹   3,051                10CM
#
#                                                  Lyrics
# 715   청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 1250  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 2095  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 3430  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 3856  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4700  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...

# %%
df = df[~df['Lyrics'].str.contains('멜론 회원|성인 인증')].reset_index(drop = True)
print(len(df))
df.head()
# Out:
# 4482
#     Title    Likes     Singer  \
# 0  후라이의 꿈  124,398  AKMU (악뮤)
# 1    연애편지   52,065        임영웅
# 2       숲  111,702        최유리
# 3   그라데이션  166,868       10CM
# 4   나만, 봄  201,198     볼빨간사춘기
#
#                                               Lyrics
# 0  저 거위도 벽을 넘어 하늘을 날을 거라고\r\n달팽이도 넓고 거친 바다 끝에 꿈을 ...
# 1  노을에 물든 저녁 하늘이\r\n오랜만에 참 좋은 저녁입니다\r\n문득 떠오른 그대 ...
# 2  난 저기 숲이 돼볼게\r\n너는 자그맣기만 한 언덕 위를\r\n오르며 날 바라볼래\...
# 3  밤은 다시 길고 깊어졌네\r\n나는 점점 너로 잠 못 들게 돼\r\n글로 적어내긴 ...
# 4  안돼 그만둬 거기까지 해\r\n더 다가가면 너 정신 못 차려\r\n안돼 그만해 꽃은...

# %%
df.to_csv('kor_folk.csv', index = False)
