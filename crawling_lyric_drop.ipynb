# %%
import pandas as pd

# %%
#df = pd.read_csv('댄스_3236 곡_240404).csv')       #3236->3225
#df = pd.read_csv('발라드_4841곡_240402.csv')       #4841->4836
#df = pd.read_csv('발라드_4999곡_240402.csv')        #4999->4995
#df = pd.read_csv('알앤비_4927곡_240402.csv')       #4927->4889
#df = pd.read_csv('인디_5000곡_240402.csv')         #5000->4938
#df = pd.read_csv('트로트_4990곡_240404.csv')        #4990->4721
#df = pd.read_csv('락메탈.csv')                      #4834->4794
#df = pd.read_csv('해외팝.csv')                      #4744->4118
#df = pd.read_csv('songs_rawdata/해외락_4544.csv')   #4544->3846
#df = pd.read_csv('songs_rawdata/해외포크_2738.csv')     #2738->1524
df = pd.read_csv('songs_rawdata/해외힙합_4498.csv')     #4498->2729
#df = df.iloc[:, 1:]
print(len(df))
print(df.isnull().sum())
# Out:
# 4498
# Title     0
# Likes     0
# Singer    0
# Lyrics    0
# dtype: int64

# %%
#알앤비 파일에 제목이 'N/A'인 노래 존재
#df = df.fillna('N/A')
#df[df['Singer'] == '주영']
# Out:
#                          Title   Likes Singer  \
# 1040           처음 (Feat. SOLE)  27,485     주영
# 1074           처음 (Feat. SOLE)  27,486     주영
# 1480        PRADA (Feat. pH-1)  19,670     주영
# 2742                     Fever     243     주영
# 2744             아름 (Feat. 죠지)   9,655     주영
# 3136  Planet Girl (Feat. pH-1)   7,323     주영
# 3534     Door (Feat. Beenzino)   7,990     주영
# 3619     요를 붙이는 사이 (Feat. 헤이즈)   4,737     주영
# 4131       Wine (Feat. G.Soul)   6,172     주영
# 4175                       N/A   6,040     주영
#
#                                                  Lyrics
# 1040  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1074  가만히 앉아 떠올려\r\n널 처음 만나 설렜었던 그날\r\n유독 느리게 걸었던 너와...
# 1480  때론 아무 생각도\r\n나질 않아 너의 기억도\r\n그저 별일 없었어\r\n아른거림...
# 2742  Looking now, There are seasons in our tale\r\n...
# 2744  너와 내가 눈을 맞출 때\r\n닫혀있던 내가 열릴 때\r\nnever thought...
# 3136  Damn\r\nGirl you got me thinkin of\r\nWith bot...
# 3534  길을 잃은 것 같아\r\n언제부터였는지\r\n모든 것이 낯설어\r\n보이지도 않는 ...
# 3619  운명은 아니겠지\r\n우연이거나 착각일 거야\r\n드라마는 없어\r\n어젯밤의\r\...
# 4131  와인 잔에 우리 기억이 담겨\r\n비워낼수록 점점 멀어져\r\n쏟아버리고\r\n깨어...
# 4175  늘 그랬듯 쉬운 건\r\n하나 없어 거울 앞에 난\r\nTrying to wave ...

# %%
df.head()
# Out:
#                                             Title    Likes       Singer  \
# 0                          Mood (Feat. Iann Dior)   86,003     24KGoldn
# 1  STAR WALKIN' (League of Legends Worlds Anthem)   33,295    Lil Nas X
# 2                              Paint The Town Red   22,360     Doja Cat
# 3   Sunflower (Spider-Man: Into the Spider-Verse)  125,283  Post Malone
# 4     Surround Sound (Feat. 21 Savage, Baby Tate)   15,047        J.I.D
#
#                                               Lyrics
# 0  Why you always in a mood\nFuckin 'round actin'...
# 1  Don’t ever say it’s over\nif I’m breathing\nRa...
# 2  Bitch I said what I said\nI’d rather be famous...
# 3  Ayy ayy ayy ayy Ooh\nOoh ooh ooh ooh Ooh\nAyy ...
# 4  I know I can't afford to stop\nfor one moment\...

# %%
df[df['Lyrics'].str.contains('멜론 회원')]
# Out:
#                           Title  Likes          Singer  \
# 42     CARNIVAL (Explicit Ver.)  2,602              ¥$
# 47       Wop (Official Version)  2,334          J-DASH
# 59                Rodeo (Remix)  3,232         Lah Pat
# 145           What You Gonna Be    977          Neffex
# 148        BURN (Explicit Ver.)  1,147              ¥$
# ...                         ...    ...             ...
# 4485                 Devastated    471  Internet Money
# 4486                      Top 5     73     Bizzy Banks
# 4490  ATM (Feat. Missy Elliott)     86     Bree Runway
# 4491                 snowflakes    116        Dominant
# 4494             time will tell     45        Idealism
#
#                                             Lyrics
# 42    [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 47    [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 59    [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 145   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 148   [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# ...                                            ...
# 4485  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4486  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4490  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4491  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
# 4494  [가사 준비중] 멜론 회원 여러분! 가사 등록을 기다리고 있어요.\n가사등록하기
#
# [1106 rows x 4 columns]

# %%
df[df['Lyrics'].str.contains('성인 인증')]
# Out:
#                                        Title   Likes          Singer  \
# 15                                   Him & I  15,873          G-Eazy
# 25                             Lose Yourself  32,085          Eminem
# 26                                   ROXANNE  98,991  Arizona Zervas
# 27                                Without Me  35,725          Eminem
# 43      Love The Way You Lie (Feat. Rihanna)  58,297          Eminem
# ...                                      ...     ...             ...
# 4444  Multi Millionaire (feat. Lil Uzi Vert)   1,921        Lil Pump
# 4467              Bankroll (Feat. AJ Tracey)     570       Lil Mosey
# 4476              10 Bands (Feat. Timbaland)     324    Joyner Lucas
# 4488                                  Slidin     444       21 Savage
# 4489                                 My Dawg     386       21 Savage
#
#                                                  Lyrics
# 15    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 25    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 26    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 27    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 43    청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# ...                                                 ...
# 4444  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4467  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4476  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4488  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
# 4489  청소년 보호법에 따라 성인 인증이 필요한 콘텐츠 입니다. 성인 인증 후 이용해 주세...
#
# [663 rows x 4 columns]

# %%
df = df[~df['Lyrics'].str.contains('멜론 회원|성인 인증')].reset_index(drop = True)
print(len(df))
df.head()
# Out:
# 2729
#                                             Title    Likes       Singer  \
# 0                          Mood (Feat. Iann Dior)   86,003     24KGoldn
# 1  STAR WALKIN' (League of Legends Worlds Anthem)   33,295    Lil Nas X
# 2                              Paint The Town Red   22,360     Doja Cat
# 3   Sunflower (Spider-Man: Into the Spider-Verse)  125,283  Post Malone
# 4     Surround Sound (Feat. 21 Savage, Baby Tate)   15,047        J.I.D
#
#                                               Lyrics
# 0  Why you always in a mood\nFuckin 'round actin'...
# 1  Don’t ever say it’s over\nif I’m breathing\nRa...
# 2  Bitch I said what I said\nI’d rather be famous...
# 3  Ayy ayy ayy ayy Ooh\nOoh ooh ooh ooh Ooh\nAyy ...
# 4  I know I can't afford to stop\nfor one moment\...

# %%
df.to_csv('eng_hiphop.csv', index = False)
